# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Whatsapp_chat.csv")
df
# Out:
#        Unnamed: 0  hours  days  months    names   timestamp
# 0               0      1    19     May  Person4  2020-05-19
# 1               1     22    19     May  Person3  2020-05-19
# 2               2     22    19     May  Person3  2020-05-19
# 3               3     22    19     May  Person1  2020-05-19
# 4               4     22    19     May  Person3  2020-05-19
# ...           ...    ...   ...     ...      ...         ...
# 51570       51570     19    12  August  Person3  2020-08-12
# 51571       51571     19    12  August  Person1  2020-08-12
# 51572       51572     20    12  August  Person3  2020-08-12
# 51573       51573     21    12  August  Person1  2020-08-12
# 51574       51574     21    12  August  Person1  2020-08-12
#
# [51575 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51575 entries, 0 to 51574
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  51575 non-null  int64
#  1   hours       51575 non-null  int64
#  2   days        51575 non-null  int64
#  3   months      51575 non-null  object
#  4   names       51575 non-null  object
#  5   timestamp   51575 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 2.4+ MB

# %%
df.drop('Unnamed', axis='columns')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-3a83c1357d10> in <module>()
# ----> 1 df.drop('Unnamed', axis='columns')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
df.columns =['ID', 'hours', 'days','months', 'names', 'timestamp']

# %%
df.drop('ID', axis='columns')
# Out:
#        hours  days  months    names   timestamp
# 0          1    19     May  Person4  2020-05-19
# 1         22    19     May  Person3  2020-05-19
# 2         22    19     May  Person3  2020-05-19
# 3         22    19     May  Person1  2020-05-19
# 4         22    19     May  Person3  2020-05-19
# ...      ...   ...     ...      ...         ...
# 51570     19    12  August  Person3  2020-08-12
# 51571     19    12  August  Person1  2020-08-12
# 51572     20    12  August  Person3  2020-08-12
# 51573     21    12  August  Person1  2020-08-12
# 51574     21    12  August  Person1  2020-08-12
#
# [51575 rows x 5 columns]

# %%
df = df[['months','names', 'timestamp','hours','days']]

# %%
df
# Out:
#        months    names   timestamp  hours  days
# 0         May  Person4  2020-05-19      1    19
# 1         May  Person3  2020-05-19     22    19
# 2         May  Person3  2020-05-19     22    19
# 3         May  Person1  2020-05-19     22    19
# 4         May  Person3  2020-05-19     22    19
# ...       ...      ...         ...    ...   ...
# 51570  August  Person3  2020-08-12     19    12
# 51571  August  Person1  2020-08-12     19    12
# 51572  August  Person3  2020-08-12     20    12
# 51573  August  Person1  2020-08-12     21    12
# 51574  August  Person1  2020-08-12     21    12
#
# [51575 rows x 5 columns]

# %%
df['names'].unique()
# Out:
# array(['Person4', 'Person3', 'Person1', 'Person2'], dtype=object)

# %%
df['months'].unique()
# Out:
# array(['May', 'June', 'July', 'August'], dtype=object)

# %%
df['hours'].unique()
# Out:
# array([ 1, 22, 23,  3,  0,  4,  5,  6, 10, 12, 15, 16, 19,  2,  7, 14, 17,
#        18, 20, 21,  8, 13, 11,  9])

# %%
df.loc[(df['names'] == 'Person1')].count()['hours']
# Out:
# 17543

# %%
df.loc[(df['names'] == 'Person1')].count()['months']
# Out:
# 17543

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='names')

# %%
sns.countplot(data= df , x='names')

# %%
sns.lineplot(x = "names", y= "hours", data =df )

# %%
sns.lineplot(x = "names", y= "months", data =df )
plt.show()

# %%
sns.lineplot(x = "names", y= "hours", data =df , hue='months')

# %%
sns.lineplot(x = "names", y= "hours", data =df , hue='months', style='months')

# %%
sns.lineplot(x = "names", y= "hours", data =df , hue='months', style='months', palette='hot')

# %%
sns.lineplot(x = "names", y= "hours", data =df , hue='months', style='months', palette='gist_gray_r')

# %%
sns.lineplot(x = "names", y= "hours", data =df , hue='months', style='months', palette='hot', markers = ["o","<", "*","^"])

# %%
sns.scatterplot(x = "names", y = "hours", data = df)

# %%
sns.scatterplot(x = "months", y = "names", data = df)

# %%
sns.scatterplot(x = "months", y = "names", data = df, hue ="hours")

# %%
sns.scatterplot(x = "names", y = "hours", data = df, hue ="months")

# %%
sns.scatterplot(x = df['names'], y =df['hours'], hue = "timestamp")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-28e32049631a> in <module>()
# ----> 1 sns.scatterplot(x = df['names'], y =df['hours'], hue = "timestamp")
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     810         x_bins=x_bins, y_bins=y_bins,
#     811         estimator=estimator, ci=ci, n_boot=n_boot,
# ...

# %%
sns.barplot(x ='months', y= 'names', data= df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-ee32674ee9f5> in <module>()
# ----> 1 sns.barplot(x ='months', y= 'names', data= df)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
# -> 3185                           errcolor, errwidth, capsize, dodge)
#    3186
# ...

# %%
sns.barplot(x ='days', y= 'hours', data= df)

# %%
sns.barplot(x ='days', y= 'hours', data= df, hue= 'months')

# %%
sns.barplot(x ='days', y= 'hours', data= df, hue= 'months', orient = 'h')

# %%
plt.figure(figsize=(16,9))
sns.barplot(x ='days', y= 'hours', data= df, hue= 'months', palette= 'hot')

# %%
plt.figure(figsize=(16,9))
 
sns.heatmap(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-6dcf7cebae6d> in <module>()
#       1 plt.figure(figsize=(16,9))
#       2
# ----> 3 sns.heatmap(df)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                           annot_kws, cbar, cbar_kws, xticklabels,
# ...

# %%
plt.figure(figsize=(15,8))
plt.title('The activation of the people per month')
sns.heatmap(x='months', hue='names', data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-2af4223f6887> in <module>()
#       1 plt.figure(figsize=(15,8))
#       2 plt.title('The activation of the people per month')
# ----> 3 sns.heatmap(x='months', hue='names', data=df)
#       4 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...

# %%
plt.figure(figsize=(15,8))
plt.title('The activation of the people per month')
sns.countplot(x='months', hue='names', data=df)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.title('the activation per day_of_week')
sns.countplot(x='day_of_week', hue='names', data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-64cbdc8882ec> in <module>()
#       1 plt.figure(figsize=(15,8))
#       2 plt.title('the activation per day_of_week')
# ----> 3 sns.countplot(x='day_of_week', hue='names', data=df)
#       4 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3600         estimator, ci, n_boot, units, seed,
#    3601         orient, color, palette, saturation,
# -> 3602         errcolor, errwidth, capsize, dodge
# ...

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['day_of_week'] = df['timestamp'].dt.day_name()

# %%
plt.figure(figsize=(15,8))
plt.title('the activation per day_of_week')
sns.countplot(x='day_of_week', hue='names', data=df)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.title('the activation per day_of_week')
sns.heatmap(x='day_of_week', y="names", data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-601667c07412> in <module>()
#       1 plt.figure(figsize=(15,8))
#       2 plt.title('the activation per day_of_week')
# ----> 3 sns.heatmap(x='day_of_week', y="names", data=df)
#       4 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...

# %%
sns.pairplot(df,vars=['months','names', 'timestamp','hours','day_of_week'], hue = 'months')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-65e66091eaca> in <module>()
# ----> 1 sns.pairplot(df,vars=['months','names', 'timestamp','hours','day_of_week'], hue = 'months')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2128         diag_kws.setdefault("fill", True)
#    2129         diag_kws.setdefault("warn_singular", False)
# -> 2130         grid.map_diag(kdeplot, **diag_kws)
#    2131
# ...
